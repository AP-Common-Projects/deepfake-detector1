# %% [markdown]
# <a href="https://colab.research.google.com/github/AP-Common-Projects/deepfake-detector1/blob/main/deepfake-detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Import the dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("chuneeb/deepfake-detection-dataset-2026")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/chuneeb/deepfake-detection-dataset-2026/1.archive...
# 100%|██████████| 131k/131k [00:00<00:00, 35.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/chuneeb/deepfake-detection-dataset-2026/versions/1

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import math
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset , DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
